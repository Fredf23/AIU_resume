# %% [markdown]
# <a href="https://colab.research.google.com/github/Fredf23/AIU_resume/blob/master/%D0%9F%D0%BE%D0%BB%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5_%D1%82%D0%BE%D0%BA%D0%B5%D0%BD%D0%B0_%D0%B4%D0%BB%D1%8F_%D0%B4%D0%BE%D1%81%D1%82%D1%83%D0%BF%D0%B0_%D0%BA_openai_(chatGPT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size=6> <b> Получение токена для доступа к openai (chatGPT)</font>

# %% [markdown]
# <ul> <font size=5> Последовательность шагов: </font>
# <li> Включите VPN </li>
# <li> Авторизируйтесь на сайте OpenAI (<a href='https://beta.openai.com/signup/'>https://beta.openai.com/signup/</a>) </li>
# <li> Перейдите на страницу работы с API-ключами (<a href='https://platform.openai.com/account/api-keys'>https://platform.openai.com/account/api-keys</a>) </li>
# </ul>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font size=3>
# <li> Нажмите на кнопку <b> Create new secret key</b></li>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font size=3>
# <li> Укажите произвольное имя для создаваемого ключа и нажмите кнопку <b> Create secret key </b></li>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font size=3>
# <li> Скопируйте и сохраните созданный ключ </li>
